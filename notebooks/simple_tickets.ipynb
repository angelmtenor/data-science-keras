# %% [markdown]
# # Simple Tickets prediction with DNN
#
# **Predicting the number of tickets requested by different clients**
#
# **Supervised Learning. Regression**
#
#
# Data taken from [Udacity's problem solving with advanced analytics](https://www.udacity.com/course/problem-solving-with-advanced-analytics--ud976)
#
# Here a neural network is effectively appllied in a simple problem usually solved with linear models

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sys.path.append("../")
import ds_boost

ds_boost.set_parent_execution_path()
ds_boost.info_system()
ds_boost.reproducible(seed=9)  # setup reproducible results from run to run using Keras
# Out:
# Path changed to /home/angel/DRIVE/data-science-keras
#
# HARDWARE:
# CPU:	Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz
# RAM:	8 GB
# GPU:	NVIDIA GeForce RTX 2070
#
# OS:	Linux-5.10.16.3-microsoft-standard-WSL2-x86_64-with-glibc2.35
#
# ENV:	/home/angel/miniconda3/envs/gpu
#
# PYTHON:	3.10.4 (main, Mar 31 2022, 08:41:55) [GCC 7.5.0]
# tensorflow                    2.9.1
# pandas                        1.4.3
# numpy                        1.23.1
#
# EXECUTION PATH: /home/angel/DRIVE/data-science-keras
# EXECUTION DATE: Mon Aug 15 13:17:34 2022

# %% [markdown]
# ## 1. Data Processing and Exploratory Data Analysis

# %%
data_path = "data/simple_tickets_data.csv"
target = ["Average Number of Tickets"]

df = pd.read_csv(data_path)
print("rows: {} \ncolumns: {} \ntarget: {}".format(*df.shape, target))
# Out:
# rows: 300
# columns: 5
# target: ['Average Number of Tickets']

# %% [markdown]
# ### Show the data

# %%
df.head()
# Out:
#   Client ID  Average Number of Tickets  Number of Employees  \
# 0     TK669                         90                  561
# 1     EY859                         85                  530
# 2     TN571                          5                   82
# 3     LJ675                         82                  491
# 4     KH713                         12                  230
#
#    Value of Contract       Industry
# 0             200000         Retail
# 1             200000         Retail
# 2              25000  Manufacturing
# 3             225000  Manufacturing
# 4              75000       Services

# %% [markdown]
# #### Numerical data

# %%
df.describe(percentiles=[0.5])
# Out:
#        Average Number of Tickets  Number of Employees  Value of Contract
# count                 300.000000           300.000000         300.000000
# mean                   44.596667           421.120000      142083.333333
# std                    42.582055           245.465265       72128.947071
# min                     1.000000            50.000000       25000.000000
# 50%                    28.000000           428.000000      150000.000000
# max                   207.000000          1116.000000      250000.000000

# %% [markdown]
# #### Missing values

# %%
ds_boost.missing(df);
# Out:
# No missing values found

# %% [markdown]
# ### Transform the data

# %% [markdown]
# #### Remove irrelevant features

# %%
df = df.drop("Client ID", axis="columns")

# %% [markdown]
# #### Classify variables

# %%
numerical = ["Number of Employees", "Value of Contract", "Average Number of Tickets"]

df = ds_boost.sort_columns_by_type(df, target, numerical)

pd.DataFrame(dict(df.dtypes), index=["Type"])[df.columns].head()  # show data types
# Out:
# 2 numerical features: 	 ['Number of Employees', 'Value of Contract']
# 1 categorical features: 	 ['Industry']
# Target: 		Average Number of Tickets (float32)
#      Number of Employees Value of Contract  Industry Average Number of Tickets
# Type             float32           float32  category                   float32

# %% [markdown]
# ### Visualize the data

# %% [markdown]
# #### Categorical features

# %%
ds_boost.show_categorical(df)

# %% [markdown]
# #### Target vs Categorical features

# %%
# ds_boost.show_target_vs_categorical(df, target) #TODO: fix

# %% [markdown]
# #### Numerical features

# %%
ds_boost.show_numerical(df, kde=True)

# %% [markdown]
# #### Target vs Numerical features

# %%
ds_boost.show_target_vs_numerical(df, target, point_size=20)

# %% [markdown]
# #### Target vs All features

# %%
g = sns.PairGrid(
    df,
    y_vars=target,
    x_vars=["Number of Employees", "Value of Contract"],
    height=7,
    hue="Industry",
    aspect=1.5,
)
g.map(sns.regplot).add_legend();

# sns.pairplot(df, hue = 'Industry', vars=['Number of Employees', 'Value of Contract'] +
#             targets, size = 4)

# %% [markdown]
# These figures suggest that a simple linear model could be used to make accurate predictions

# %% [markdown]
# #### Correlation between numerical features and target

# %%
ds_boost.correlation(df, target, figsize=(7, 4))
# Out:
# []

# %% [markdown]
# ## 2. Neural Network model

# %% [markdown]
# ### Select the features

# %%
droplist = []  # features to drop

# For the model 'data' instead of 'df'
data = df.copy()
data.drop(droplist, axis="columns", inplace=True)
data.head(3)
# Out:
#    Number of Employees  Value of Contract       Industry  \
# 0                561.0           200000.0         Retail
# 1                530.0           200000.0         Retail
# 2                 82.0            25000.0  Manufacturing
#
#    Average Number of Tickets
# 0                       90.0
# 1                       85.0
# 2                        5.0

# %% [markdown]
# ### Scale numerical variables
# Shift and scale numerical variables to a standard normal distribution. The scaling factors are saved to be used for predictions.

# %%
data, scale_param = ds_boost.scale(data)

# %% [markdown]
# ### Create dummy features
# Replace categorical features (no target) with dummy features

# %%
data, dict_dummies = ds_boost.replace_by_dummies(data, target)

model_features = [f for f in data if f not in target]  # sorted neural network inputs

data.head(3)
# Out:
#    Number of Employees  Value of Contract  Average Number of Tickets  \
# 0             0.569857            0.80296                   1.066255
# 1             0.443566            0.80296                   0.948835
# 2            -1.381540           -1.62325                  -0.929891
#
#   Industry_Manufacturing Industry_Retail Industry_Services
# 0                      0               1                 0
# 1                      0               1                 0
# 2                      1               0                 0

# %% [markdown]
# ### Split the data into training and test set
#
# Data leakage: Test set hidden when training the model, but seen when preprocessing the dataset
#
# No validation set will be used here (300 samples)

# %%
test_size = 0.2
random_state = 0

from sklearn.model_selection import train_test_split

train, test = train_test_split(data, test_size=test_size, random_state=random_state)

# Separate the data into features and target (x=features, y=target)
x_train, y_train = train.drop(target, axis=1).values, train[target].values
x_test, y_test = test.drop(target, axis=1).values, test[target].values

# %% [markdown]
# One-hot encode the output not needed for regression

# %%
print("train size \t X:{} \t Y:{}".format(x_train.shape, y_train.shape))
print("test size  \t X:{} \t Y:{} ".format(x_test.shape, y_test.shape))
# Out:
# train size 	 X:(240, 5) 	 Y:(240, 1)
# test size  	 X:(60, 5) 	 Y:(60, 1)

# %% [markdown]
# ### Build the Neural Network for Regression

# %%
from keras.models import Sequential
from keras.layers.core import Dense, Dropout


def build_nn(input_size, output_size, summary=False):

    input_nodes = input_size
    weights = keras.initializers.RandomNormal(stddev=0.001)

    model = Sequential()
    model.add(
        Dense(
            input_nodes,
            input_dim=input_size,
            activation="tanh",
            kernel_initializer=weights,
            bias_initializer=weights,
        )
    )

    model.add(Dense(1, activation=None, kernel_initializer=weights, bias_initializer=weights))

    model.compile(loss="mean_squared_error", optimizer="adam")

    if summary:
        model.summary()

    return model

# %% [markdown]
# ### Train the Neural Network

# %%
from time import time
import keras

model_path = os.path.join("models", "simple_tickets.h5")


def train_nn(model, x_train, y_train, validation_data=None, path=False, show=True):
    """
    Train the neural network model. If no validation_data is provided, a split for validation
    will be used
    """

    if show:
        print("Training ....")

    # callbacks = [keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, verbose=0)]
    t0 = time()

    history = model.fit(
        x_train,
        y_train,
        epochs=30,
        batch_size=16,
        validation_split=0,
        validation_data=validation_data,
        callbacks=None,
        verbose=0,
    )

    if show:
        print("time: \t {:.1f} s".format(time() - t0))
        ds_boost.show_training(history)

    if path:
        model.save(path)
        print("\nModel saved at", path)

    return history


model = None
model = build_nn(x_train.shape[1], y_train.shape[1], summary=False)
train_nn(model, x_train, y_train, validation_data=None, path=model_path)

from sklearn.metrics import r2_score

ypred_train = model.predict(x_train)
# ypred_val = model.predict(x_val)
print("Training   R2-score: \t{:.3f}".format(r2_score(y_train, ypred_train)))
# print('Validation R2-score: \t{:.3f}'.format(r2_score(y_val, ypred_val)))
# Out:
# Training ....
# time: 	 2.9 s
# Training loss:  	0.3764
#
# Model saved at models/simple_tickets.h5
# 8/8 [==============================] - 0s 2ms/step
# Training   R2-score: 	0.602

# %% [markdown]
# ### Evaluate the model

# %%
# model = keras.models.load_model(model_path)
# print("Model loaded:", model_path)


def evaluate_nn(model, x_test, y_test):

    score = model.evaluate(x_test, y_test, verbose=0)
    print("\nTest loss:\t\t{:.4f}".format(score))

    ypred_test = model.predict(x_test)
    print("\nTest R2-score: \t\t{:.3f}".format(r2_score(y_test, ypred_test)))


evaluate_nn(model, x_test, y_test)
# Out:
# Test loss:		0.6119
# 2/2 [==============================] - 0s 4ms/step
#
# Test R2-score: 		0.492

# %% [markdown]
# ### Make predictions

# %%
def predict_nn(model, x_test, target):
    """Return a dataframe with actual and predicted targets in original scale"""

    for t in target:
        pred = model.predict(x_test, verbose=0)
        restore_pred = pred * scale_param[t][1] + scale_param[t][0]
        restore_pred = restore_pred.round()

        restore_y = y_test * scale_param[t][1] + scale_param[t][0]
        restore_y = restore_y.round()

        pred_label = "Predicted_" + t
        error_label = t + " error (%)"

        pred_df = pd.DataFrame({t: np.squeeze(restore_y), pred_label: np.squeeze(restore_pred)})

        pred_df[error_label] = ((pred_df[pred_label] - pred_df[t]) * 100 / pred_df[t]).round(1)

        print(t, ". Prediction error:")
        print("Mean: \t {:.2f}%".format(pred_df[error_label].mean()))
        print("Stddev:  {:.2f}%".format(pred_df[error_label].std()))
        sns.distplot(pred_df[error_label])
        plt.xlim(xmin=-600, xmax=600)

    return pred_df


pred_df = predict_nn(model, x_test, target)
# Out:
# Average Number of Tickets . Prediction error:
# Mean: 	 77.97%
# Stddev:  201.03%
# /home/angel/miniconda3/envs/gpu/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
pred_df.head()
# Out:
#    Average Number of Tickets  Predicted_Average Number of Tickets  \
# 0                       56.0                                 90.0
# 1                        9.0                                 29.0
# 2                       32.0                                 36.0
# 3                       34.0                                 28.0
# 4                       50.0                                 64.0
#
#    Average Number of Tickets error (%)
# 0                            60.700001
# 1                           222.199997
# 2                            12.500000
# 3                           -17.600000
# 4                            28.000000

# %% [markdown]
# The prediction error (%) can be especially high when the number of tickets is low. The absolute error could be a better indicator here.

# %% [markdown]
# ### Compare with linear regression

# %%
from sklearn.linear_model import LinearRegression

reg = LinearRegression()
reg.fit(x_train, y_train)
pred = reg.predict(x_test)

t = target[0]
restore_pred = pred * scale_param[t][1] + scale_param[t][0]
restore_pred = restore_pred.round()

restore_y = y_test * scale_param[t][1] + scale_param[t][0]
restore_y = restore_y.round()

pred_label = "Predicted_" + t
error_label = t + " error (%)"

pred_df = pd.DataFrame({t: np.squeeze(restore_y), pred_label: np.squeeze(restore_pred)})

pred_df[error_label] = ((pred_df[pred_label] - pred_df[t]) * 100 / pred_df[t]).round(1)

print(t, ". Prediction error:")
print("Mean: \t {:.2f}%".format(pred_df[error_label].mean()))
print("Stddev:  {:.2f}%".format(pred_df[error_label].std()))
sns.distplot(pred_df[error_label])
plt.xlim(xmin=-600, xmax=600)
# Out:
# Average Number of Tickets . Prediction error:
# Mean: 	 85.51%
# Stddev:  214.45%
# /home/angel/miniconda3/envs/gpu/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# (-600.0, 600.0)

# %% [markdown]
# The mean and standard deviation of the error is higher with the linear model.

# %% [markdown]
# ### Compare with classical ML

# %%
ds_boost.ml_regression(x_train, y_train, x_test, y_test)
# Out:
# Linear
# KNeighbors
# Random Forest
# LGBM
#                Time (s)  Test loss  Test R2 score
# LGBM                0.5       0.61           0.50
# Linear              0.0       0.62           0.48
# Random Forest       0.2       0.69           0.43
# KNeighbors          0.0       0.76           0.36
